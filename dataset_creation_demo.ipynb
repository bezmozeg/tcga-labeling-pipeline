# %%
from labeling_util import *

# %% [markdown]
# ## get data for specific projects

# %%
data = get_projects_info(['TCGA-LUAD','TCGA-GBM','ABCD'])
# Out:
# looking for project names in GDC database.
# --------------------------------------------------------------------------------
# Projects found in GDC: ['TCGA-GBM', 'TCGA-LUAD']
# --------------------------------------------------------------------------------
# looking for cases for project: TCGA-GBM
# retrieved 617 cases in the TCGA-GBM project
# downloading maf file for project TCGA-GBM
# downloaded file: TCGA.GBM.muse.59a84472-27d4-497c-8f37-8bc447ff9374.DR-10.0.somatic.maf.gz
# file extracted to: TCGA-GBM-maf.tsv
# C:\Users\Richard\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (19,20,28,87,88,98) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# --------------------------------------------------------------------------------
# looking for cases for project: TCGA-LUAD
# retrieved 585 cases in the TCGA-LUAD project
# downloading maf file for project TCGA-LUAD
# downloaded file: TCGA.LUAD.muse.6f5cde97-d259-414f-8122-6d0d66f49b74.DR-10.0.somatic.maf.gz
# file extracted to: TCGA-LUAD-maf.tsv
# C:\Users\Richard\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3254: DtypeWarning: Columns (86,87,88,98,118) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# --------------------------------------------------------------------------------
# done

# %% [markdown]
# ## split cases to sets

# %%
#get all the case ids as keys from the case to images mapping
all_cases = list(data['case to images'].keys())
test_set = all_cases[:5]

# %% [markdown]
# ## get image file names for the set

# %%
test_set_images = list(map( lambda x : data['case to images'][x], test_set))
#flatten
test_set_images = [img for case in test_set_images for img in case]

# %% [markdown]
# ## get labels for each image file

# %%
#get sample ids to match with labels
sample_ids = list(map( lambda x : data['image to sample'][x], test_set_images))
test_set_labels = pd.DataFrame()
for sample in sample_ids:
    test_set_labels = test_set_labels.append(data['labels'][data['labels']['sample.barcode']==sample])
test_set_labels
# Out:
#     case_barcode   project                               case_id  \
# 0   TCGA-14-0871  TCGA-GBM  72f88d18-03be-4b51-9f4a-1151521b7292
# 0   TCGA-14-0871  TCGA-GBM  72f88d18-03be-4b51-9f4a-1151521b7292
# 0   TCGA-14-0871  TCGA-GBM  72f88d18-03be-4b51-9f4a-1151521b7292
# 1   TCGA-14-0871  TCGA-GBM  72f88d18-03be-4b51-9f4a-1151521b7292
# 1   TCGA-14-0871  TCGA-GBM  72f88d18-03be-4b51-9f4a-1151521b7292
# 3   TCGA-32-1977  TCGA-GBM  4294ae28-445b-4f4f-823a-dac4cecfaaf0
# 3   TCGA-32-1977  TCGA-GBM  4294ae28-445b-4f4f-823a-dac4cecfaaf0
# 5   TCGA-74-6573  TCGA-GBM  8d0d7a7e-8fae-437d-9b39-f2f17d0f5e4f
# 5   TCGA-74-6573  TCGA-GBM  8d0d7a7e-8fae-437d-9b39-f2f17d0f5e4f
# 6   TCGA-74-6573  TCGA-GBM  8d0d7a7e-8fae-437d-9b39-f2f17d0f5e4f
# 8   TCGA-19-5956  TCGA-GBM  7e70a318-3acc-42f3-8287-158a2199f0bc
# 9   TCGA-19-5956  TCGA-GBM  7e70a318-3acc-42f3-8287-158a2199f0bc
# 9   TCGA-19-5956  TCGA-GBM  7e70a318-3acc-42f3-8287-158a2199f0bc
# 10  TCGA-74-6581  TCGA-GBM  28629bf9-f447-4650-8fc2-53f1e938ab71
#
#     demographic.submitter_id  demographic.year_of_death  \
# 0   TCGA-14-0871_demographic                     2000.0
# 0   TCGA-14-0871_demographic                     2000.0
# 0   TCGA-14-0871_demographic                     2000.0
# 1   TCGA-14-0871_demographic                     2000.0
# 1   TCGA-14-0871_demographic                     2000.0
# 3   TCGA-32-1977_demographic                        NaN
# 3   TCGA-32-1977_demographic                        NaN
# 5   TCGA-74-6573_demographic                     2009.0
# 5   TCGA-74-6573_demographic                     2009.0
# 6   TCGA-74-6573_demographic                     2009.0
# 8   TCGA-19-5956_demographic                        NaN
# 9   TCGA-19-5956_demographic                        NaN
# 9   TCGA-19-5956_demographic                        NaN
# 10  TCGA-74-6581_demographic                        NaN
#
#    demographic.vital_status   demographic.ethnicity  \
# 0                      Dead            not reported
# 0                      Dead            not reported
# 0                      Dead            not reported
# 1                      Dead            not reported
# 1                      Dead            not reported
# 3                     Alive      hispanic or latino
# 3                     Alive      hispanic or latino
# 5                      Dead            not reported
# 5                      Dead            not reported
# 6                      Dead            not reported
# 8                      Dead  not hispanic or latino
# 9                      Dead  not hispanic or latino
# 9                      Dead  not hispanic or latino
# 10                    Alive            not reported
#
#     demographic.days_to_death demographic.gender  demographic.year_of_birth  \
# 0                       880.0             female                     1924.0
# 0                       880.0             female                     1924.0
# 0                       880.0             female                     1924.0
# 1                       880.0             female                     1924.0
# 1                       880.0             female                     1924.0
# 3                         NaN             female                     1946.0
# 3                         NaN             female                     1946.0
# 5                       105.0               male                     1942.0
# 5                       105.0               male                     1942.0
# 6                       105.0               male                     1942.0
# 8                       684.0             female                     1957.0
# 9                       684.0             female                     1957.0
# 9                       684.0             female                     1957.0
# 10                        NaN               male                     1933.0
#
#     ... diagnose.ann_arbor_pathologic_stage  sample.biospecimen_laterality  \
# 0   ...                                 NaN                            NaN
# 0   ...                                 NaN                            NaN
# 0   ...                                 NaN                            NaN
# 1   ...                                 NaN                            NaN
# 1   ...                                 NaN                            NaN
# 3   ...                                 NaN                            NaN
# 3   ...                                 NaN                            NaN
# 5   ...                                 NaN                            NaN
# 5   ...                                 NaN                            NaN
# 6   ...                                 NaN                            NaN
# 8   ...                                 NaN                            NaN
# 9   ...                                 NaN                            NaN
# 9   ...                                 NaN                            NaN
# 10  ...                                 NaN                            NaN
#
#    sample.passage_count sample.method_of_sample_procurement  \
# 0                   NaN                                 NaN
# 0                   NaN                                 NaN
# 0                   NaN                                 NaN
# 1                   NaN                                 NaN
# 1                   NaN                                 NaN
# 3                   NaN                                 NaN
# 3                   NaN                                 NaN
# 5                   NaN                                 NaN
# 5                   NaN                                 NaN
# 6                   NaN                                 NaN
# 8                   NaN                                 NaN
# 9                   NaN                                 NaN
# 9                   NaN                                 NaN
# 10                  NaN                                 NaN
#
#     sample.diagnosis_pathologically_confirmed  \
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 1                                         NaN
# 1                                         NaN
# 3                                         NaN
# 3                                         NaN
# 5                                         NaN
# 5                                         NaN
# 6                                         NaN
# 8                                         NaN
# 9                                         NaN
# 9                                         NaN
# 10                                        NaN
#
#    sample.biospecimen_anatomic_site sample.distance_normal_to_tumor  \
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 1                               NaN                             NaN
# 3                               NaN                             NaN
# 3                               NaN                             NaN
# 5                               NaN                             NaN
# 5                               NaN                             NaN
# 6                               NaN                             NaN
# 8                               NaN                             NaN
# 9                               NaN                             NaN
# 9                               NaN                             NaN
# 10                              NaN                             NaN
#
#    sample.growth_rate sample.catalog_reference sample.distributor_reference
# 0                 NaN                      NaN                          NaN
# 0                 NaN                      NaN                          NaN
# 0                 NaN                      NaN                          NaN
# 1                 NaN                      NaN                          NaN
# 1                 NaN                      NaN                          NaN
# 3                 NaN                      NaN                          NaN
# 3                 NaN                      NaN                          NaN
# 5                 NaN                      NaN                          NaN
# 5                 NaN                      NaN                          NaN
# 6                 NaN                      NaN                          NaN
# 8                 NaN                      NaN                          NaN
# 9                 NaN                      NaN                          NaN
# 9                 NaN                      NaN                          NaN
# 10                NaN                      NaN                          NaN
#
# [14 rows x 150 columns]
